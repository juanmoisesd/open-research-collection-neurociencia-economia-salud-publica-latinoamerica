# %% [markdown]
# # Análisis: Open Research Collection — Juan Moisés de la Serna Tuya: Neurociencia, Economía Conductual, Salud Pública y Demografía en América Latina (2024-2025)
#
# **DOI:** https://doi.org/10.5281/zenodo.19151868
# **Autor:** de la Serna, Juan Moisés
# **Institución:** Universidad Internacional de La Rioja (UNIR)
# **Año:** 2025

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

print("Entorno configurado correctamente")

# %% [markdown]
# ## Carga de datos
#
# Esta colección agrupa múltiples datasets sobre neurociencia, economía conductual, salud pública y demografía en América Latina.

# %%
# Cargar datos del dataset principal
# df = pd.read_csv("data.csv")
# df.head()

# %% [markdown]
# ## Cómo citar
#
# ```
# de la Serna, Juan Moisés (2025). Open Research Collection — Juan Moisés de la Serna Tuya: Neurociencia, Economía Conductual, Salud Pública y Demografía en América Latina (2024-2025). Zenodo. https://doi.org/10.5281/zenodo.19151868
# ```
